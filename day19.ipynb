# %%
print("hello")
# Out:
# hello

# %% [markdown]
# # 1 import dataset

# %% [markdown]
# over here will import the dataset

# %%
import pandas as pd

# %%
df=pd.read_csv('WA_Fn-UseC_-HR-Employee-Attrition.csv')

# %%
df
# Out:
#       Age Attrition     BusinessTravel  DailyRate              Department  \
# 0      41       Yes      Travel_Rarely       1102                   Sales
# 1      49        No  Travel_Frequently        279  Research & Development
# 2      37       Yes      Travel_Rarely       1373  Research & Development
# 3      33        No  Travel_Frequently       1392  Research & Development
# 4      27        No      Travel_Rarely        591  Research & Development
# ...   ...       ...                ...        ...                     ...
# 1465   36        No  Travel_Frequently        884  Research & Development
# 1466   39        No      Travel_Rarely        613  Research & Development
# 1467   27        No      Travel_Rarely        155  Research & Development
# 1468   49        No  Travel_Frequently       1023                   Sales
# 1469   34        No      Travel_Rarely        628  Research & Development
#
#       DistanceFromHome  Education EducationField  EmployeeCount  \
# ...

# %%
pd.read_csv('WA_Fn-UseC_-HR-Employee-Attrition.csv',nrows=100)
# Out:
#     Age Attrition     BusinessTravel  DailyRate              Department  \
# 0    41       Yes      Travel_Rarely       1102                   Sales
# 1    49        No  Travel_Frequently        279  Research & Development
# 2    37       Yes      Travel_Rarely       1373  Research & Development
# 3    33        No  Travel_Frequently       1392  Research & Development
# 4    27        No      Travel_Rarely        591  Research & Development
# ..  ...       ...                ...        ...                     ...
# 95   54        No      Travel_Rarely       1217  Research & Development
# 96   24        No      Travel_Rarely       1353                   Sales
# 97   28        No         Non-Travel        120                   Sales
# 98   58        No      Travel_Rarely        682                   Sales
# 99   44        No         Non-Travel        489  Research & Development
#
#     DistanceFromHome  Education    EducationField  EmployeeCount  \
# ...

# %%
def rename(name):
    if name == "Travel_Rarely":
        return"noFUN"
    else:
        return name

# %%
rename("Travel_Rarely")
# Out:
# 'noFUN'

# %%
pd.read_csv('WA_Fn-UseC_-HR-Employee-Attrition.csv',converters={'BusinessTravel':rename})
# Out:
#       Age Attrition     BusinessTravel  DailyRate              Department  \
# 0      41       Yes              noFUN       1102                   Sales
# 1      49        No  Travel_Frequently        279  Research & Development
# 2      37       Yes              noFUN       1373  Research & Development
# 3      33        No  Travel_Frequently       1392  Research & Development
# 4      27        No              noFUN        591  Research & Development
# ...   ...       ...                ...        ...                     ...
# 1465   36        No  Travel_Frequently        884  Research & Development
# 1466   39        No              noFUN        613  Research & Development
# 1467   27        No              noFUN        155  Research & Development
# 1468   49        No  Travel_Frequently       1023                   Sales
# 1469   34        No              noFUN        628  Research & Development
#
#       DistanceFromHome  Education EducationField  EmployeeCount  \
# ...

# %%
dfs=pd.read_csv('WA_Fn-UseC_-HR-Employee-Attrition.csv',chunksize=500)

# %%
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[22], line 2
#       1 for chunks in dfs:
# ----> 2     print(chunk.shape)
#
# NameError: name 'chunk' is not defined

# %%
df.shape
# Out:
# (1470, 35)

# %%
df.sample(5)
# Out:
#       Age Attrition     BusinessTravel  DailyRate              Department  \
# 181    34        No      Travel_Rarely        629  Research & Development
# 988    41        No  Travel_Frequently       1200  Research & Development
# 1372   39        No      Travel_Rarely        867  Research & Development
# 74     36        No      Travel_Rarely        132  Research & Development
# 1357   42        No      Travel_Rarely       1396  Research & Development
#
#       DistanceFromHome  Education EducationField  EmployeeCount  \
# 181                 27          2        Medical              1
# 988                 22          3  Life Sciences              1
# 1372                 9          2        Medical              1
# 74                   6          3  Life Sciences              1
# 1357                 6          3        Medical              1
#
#       EmployeeNumber  ...  RelationshipSatisfaction StandardHours  \
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1470 entries, 0 to 1469
# Data columns (total 35 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Age                       1470 non-null   int64
#  1   Attrition                 1470 non-null   object
#  2   BusinessTravel            1470 non-null   object
#  3   DailyRate                 1470 non-null   int64
#  4   Department                1470 non-null   object
#  5   DistanceFromHome          1470 non-null   int64
#  6   Education                 1470 non-null   int64
#  7   EducationField            1470 non-null   object
#  8   EmployeeCount             1470 non-null   int64
#  9   EmployeeNumber            1470 non-null   int64
#  10  EnvironmentSatisfaction   1470 non-null   int64
#  11  Gender                    1470 non-null   object
#  12  HourlyRate                1470 non-null   int64
#  13  JobInvolvement            1470 non-null   int64
# ...

# %%
df.isnulll().sum()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_20000\4085122558.py in ?()
# ----> 1 df.isnulll().sum()
#
# ~\anaconda3\Lib\site-packages\pandas\core\generic.py in ?(self, name)
#    6295             and name not in self._accessors
#    6296             and self._info_axis._can_hold_identifiers_and_holds_name(name)
#    6297         ):
#    6298             return self[name]
# -> 6299         return object.__getattribute__(self, name)
#
# AttributeError: 'DataFrame' object has no attribute 'isnulll'

# %%
df.describe()
# Out:
#                Age    DailyRate  DistanceFromHome    Education  EmployeeCount  \
# count  1470.000000  1470.000000       1470.000000  1470.000000         1470.0
# mean     36.923810   802.485714          9.192517     2.912925            1.0
# std       9.135373   403.509100          8.106864     1.024165            0.0
# min      18.000000   102.000000          1.000000     1.000000            1.0
# 25%      30.000000   465.000000          2.000000     2.000000            1.0
# 50%      36.000000   802.000000          7.000000     3.000000            1.0
# 75%      43.000000  1157.000000         14.000000     4.000000            1.0
# max      60.000000  1499.000000         29.000000     5.000000            1.0
#
#        EmployeeNumber  EnvironmentSatisfaction   HourlyRate  JobInvolvement  \
# count     1470.000000              1470.000000  1470.000000     1470.000000
# mean      1024.865306                 2.721769    65.891156        2.729932
# ...

# %%
df.duplicated().sum()
# Out:
# 0

# %%
df.corr(numeric_only=True)['DailyRate']
# Out:
# Age                         0.010661
# DailyRate                   1.000000
# DistanceFromHome           -0.004985
# Education                  -0.016806
# EmployeeCount                    NaN
# EmployeeNumber             -0.050990
# EnvironmentSatisfaction     0.018355
# HourlyRate                  0.023381
# JobInvolvement              0.046135
# JobLevel                    0.002966
# JobSatisfaction             0.030571
# MonthlyIncome               0.007707
# MonthlyRate                -0.032182
# NumCompaniesWorked          0.038153
# PercentSalaryHike           0.022704
# PerformanceRating           0.000473
# RelationshipSatisfaction    0.007846
# StandardHours                    NaN
# StockOptionLevel            0.042143
# TotalWorkingYears           0.014515
# TrainingTimesLastYear       0.002453
# WorkLifeBalance            -0.037848
# YearsAtCompany             -0.034055
# YearsInCurrentRole          0.009932
# YearsSinceLastPromotion    -0.033229
# ...
